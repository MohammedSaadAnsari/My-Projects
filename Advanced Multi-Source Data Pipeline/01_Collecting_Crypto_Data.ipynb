# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd

url = "https://api.coingecko.com/api/v3/coins/markets"

params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 100,
    "page": 1,
    "sparkline": False
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()

    df = pd.DataFrame(data)

    print(df.head())
    print(df.columns)

    df.to_csv("crypto_data.csv", index=False)

    print("Data collected successfully!")
else:
    print("Error:", response.status_code)
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...   79521.000000
# 1  https://coin-images.coingecko.com/coins/images...    2511.780000
# 2  https://coin-images.coingecko.com/coins/images...       0.999752
# 3  https://coin-images.coingecko.com/coins/images...     756.770000
# 4  https://coin-images.coingecko.com/coins/images...       1.430000
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1596907659479                1            1596917360999  3.401496e+10
# 1   306518201478                2             306518201478  1.198981e+10
# 2   183414602480                3             188880189741  5.250357e+10
# 3   100774371434                4             100774365637  9.948938e+08
# 4    89895396694                5             143251551449  2.588803e+09
#
#        high_24h  ...  total_supply    max_supply        ath  \
# 0  79701.000000  ...  2.008179e+07  2.100000e+07  126080.00
# 1   2521.510000  ...  1.220326e+08           NaN    4946.05
# 2      0.999995  ...  1.889271e+11           NaN       1.32
# 3    757.670000  ...  1.331614e+08  2.000000e+08    1369.99
# 4      1.450000  ...  9.998563e+10  1.000000e+11       3.65
#
#    ath_change_percentage                  ath_date        atl  \
# 0              -36.92831  2025-10-06T10:57:42.000Z  67.810000
# 1              -49.21649  2025-08-24T11:21:03.000Z   0.432979
# 2              -24.43837  2018-07-23T16:00:00.000Z   0.572521
# 3              -44.76087  2025-10-13T00:41:24.000Z   0.039818
# 4              -60.71386  2025-07-17T19:40:53.000Z   0.002686
#
#    atl_change_percentage                  atl_date  \
# 0           1.171716e+05  2013-07-05T16:00:00.000Z
# 1           5.800154e+05  2015-10-19T16:00:00.000Z
# 2           7.462283e+01  2015-03-01T16:00:00.000Z
# 3           1.900491e+06  2017-10-18T16:00:00.000Z
# 4           5.322878e+04  2014-05-21T16:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2026-09-09T09:14:20.000Z
# 1  {'times': 41.23061842109489, 'currency': 'btc'...  2026-09-09T09:14:20.000Z
# 2                                               None  2026-09-09T09:14:20.000Z
# 3                                               None  2026-09-09T09:14:20.000Z
# 4                                               None  2026-09-09T09:14:20.000Z
#
# [5 rows x 26 columns]
# Index(['id', 'symbol', 'name', 'image', 'current_price', 'market_cap',
#        'market_cap_rank', 'fully_diluted_valuation', 'total_volume',
#        'high_24h', 'low_24h', 'price_change_24h',
#        'price_change_percentage_24h', 'market_cap_change_24h',
#        'market_cap_change_percentage_24h', 'circulating_supply',
#        'total_supply', 'max_supply', 'ath', 'ath_change_percentage',
#        'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi',
#        'last_updated'],
#       dtype='object')
# Data collected successfully!
